# %%
class Game:
  def __init__(self, name, tags, release_year, score, price, developer):
    self.tags = tags
    self.release_year = release_year
    self.score = score
    self.price = price
    self.developer = developer
    self.name = name

# %%
mc = Game('minecraft', ['pvp', 'open world'], 2009, 10, 20, 'Mojang')
mc.__dict__
# Out:
# {'tags': ['pvp', 'open world'],
#  'release_year': 2009,
#  'score': 10,
#  'price': 20,
#  'developer': 'Mojang',
#  'name': 'minecraft'}
